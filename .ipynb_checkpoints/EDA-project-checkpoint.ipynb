# %%
#Importing packages
import pandas as pd
from sqlalchemy import create_engine

print("Libraries imported!")
# Out:
# Libraries imported!

# %%
#Loading the data

#Define the number of weeks
num_weeks = [210320, 210313, 210306, 210227, 210220, 210213, 210206, 210130, 
             210123, 210116, 210109, 210102, 201226, 201219, 201212, 201205]

#Define the base data_url
data_url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"

#Create the empty list to store each week's dataframe
data_list = []

#Loop through each week in the list
for week in num_weeks:
    
    #Use pandas to read in the data
    data = pd.read_csv(data_url.format(week))
    
    #Append each dataframe into the data_list
    data_list.append(data)

#Concatenate them all into the big dataframe called
df = pd.concat(data_list, ignore_index=True)

#Export the df into csv file called all_combined.csv
new_df = df.set_index('C/A')
new_df.to_csv("data/all_combined.csv")

# %%
#Create sql engine
engine = create_engine("sqlite:///mta.db")

#Load db using real_sql
all_data = pd.read_sql('SELECT * FROM mta_data;', engine)

#Display first 5 rows
all_data.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\metis\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#
# ~\Anaconda3\envs\metis\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     680     def do_execute(self, cursor, statement, parameters, context=None):
# --> 681         cursor.execute(statement, parameters)
#     682
#
# OperationalError: no such table: mta_data
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-2-175f7bb95d66> in <module>
#       3
#       4 #Load db using real_sql
# ----> 5 all_data = pd.read_sql('SELECT * FROM mta_data;', engine)
#       6
#       7 #Display first 5 rows
#
# ~\Anaconda3\envs\metis\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     508         )
#     509     else:
# --> 510         return pandas_sql.read_query(
#     511             sql,
#     512             index_col=index_col,
#
# ~\Anaconda3\envs\metis\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1292         args = _convert_params(sql, params)
#    1293
# -> 1294         result = self.execute(*args)
#    1295         columns = result.keys()
#    1296
#
# ~\Anaconda3\envs\metis\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1160     def execute(self, *args, **kwargs):
#    1161         """Simple passthrough to SQLAlchemy connectable"""
# -> 1162         return self.connectable.execution_options().execute(*args, **kwargs)
#    1163
#    1164     def read_table(
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~\Anaconda3\envs\metis\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~\Anaconda3\envs\metis\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    3007         """
#    3008         connection = self.connect(close_with_result=True)
# -> 3009         return connection.execute(statement, *multiparams, **params)
#    3010
#    3011     @util.deprecated_20(
#
# ~\Anaconda3\envs\metis\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1183             )
#    1184
# -> 1185             return self._exec_driver_sql(
#    1186                 statement,
#    1187                 multiparams,
#
# ~\Anaconda3\envs\metis\lib\site-packages\sqlalchemy\engine\base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1482
#    1483         dialect = self.dialect
# -> 1484         ret = self._execute_context(
#    1485             dialect,
#    1486             dialect.execution_ctx_cls._init_statement,
#
# ~\Anaconda3\envs\metis\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1746
#    1747         except BaseException as e:
# -> 1748             self._handle_dbapi_exception(
#    1749                 e, statement, parameters, cursor, context
#    1750             )
#
# ~\Anaconda3\envs\metis\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1927                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1928             elif should_wrap:
# -> 1929                 util.raise_(
#    1930                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1931                 )
#
# ~\Anaconda3\envs\metis\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     196
#     197         try:
# --> 198             raise exception
#     199         finally:
#     200             # credit to
#
# ~\Anaconda3\envs\metis\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1703                             break
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#    1707                     )
#
# ~\Anaconda3\envs\metis\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     679
#     680     def do_execute(self, cursor, statement, parameters, context=None):
# --> 681         cursor.execute(statement, parameters)
#     682
#     683     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such table: mta_data
# [SQL: SELECT * FROM mta_data;]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
#We see the first row in the all_data df is the headers, so let's drop it and reset index
all_data = all_data.drop(0, axis = 0).reset_index(drop=True)
all_data
# Out:
#             CA  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0         A002  R051  02-00-00          59 ST  NQR456W      BMT  03/13/2021
# 1         A002  R051  02-00-00          59 ST  NQR456W      BMT  03/13/2021
# 2         A002  R051  02-00-00          59 ST  NQR456W      BMT  03/13/2021
# 3         A002  R051  02-00-00          59 ST  NQR456W      BMT  03/13/2021
# 4         A002  R051  02-00-00          59 ST  NQR456W      BMT  03/13/2021
# ...        ...   ...       ...            ...      ...      ...         ...
# 3353756  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/04/2020
# 3353757  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/04/2020
# 3353758  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/04/2020
# 3353759  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/04/2020
# 3353760  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  12/04/2020
#
#              TIME     DESC  ENTRIES    EXITS
# 0        03:00:00  REGULAR  7543925  2573549
# 1        07:00:00  REGULAR  7543931  2573559
# 2        11:00:00  REGULAR  7543970  2573622
# 3        15:00:00  REGULAR  7544072  2573700
# 4        19:00:00  REGULAR  7544219  2573729
# ...           ...      ...      ...      ...
# 3353756  04:00:00  REGULAR     5554      541
# 3353757  08:00:00  REGULAR     5554      541
# 3353758  12:00:00  REGULAR     5554      541
# 3353759  16:00:00  REGULAR     5554      541
# 3353760  20:00:00  REGULAR     5554      541
#
# [3353761 rows x 11 columns]

# %%
all_data.shape
# Out:
# (3353761, 11)

# %%
all_data.dtypes
# Out:
# CA          object
# UNIT        object
# SCP         object
# STATION     object
# LINENAME    object
# DIVISION    object
# DATE        object
# TIME        object
# DESC        object
# ENTRIES     object
# EXITS       object
# dtype: object

# %%
all_data.columns
# Out:
# Index(['CA', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
all_data['DATE'] = pd.to_datetime(all_data['DATE'])
all_data.head()
# Out:
#      CA  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2021-03-13  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2021-03-13  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2021-03-13  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2021-03-13  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2021-03-13  19:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  7543925  2573549
# 1  REGULAR  7543931  2573559
# 2  REGULAR  7543970  2573622
# 3  REGULAR  7544072  2573700
# 4  REGULAR  7544219  2573729

# %%
all_data.describe()
# Out:
# <ipython-input-51-14a90e0e01c9>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   all_data.describe()
#              CA     UNIT       SCP         STATION LINENAME DIVISION  \
# count   3353761  3353761   3353761         3353761  3353761  3353761
# unique      750      469       228             378      114        6
# top       PTH22     R549  00-00-00  34 ST-PENN STA        1      IRT
# freq      28760    45896    311494           68287   410308  1202140
# first       NaN      NaN       NaN             NaN      NaN      NaN
# last        NaN      NaN       NaN             NaN      NaN      NaN
#
#                        DATE      TIME     DESC    ENTRIES      EXITS
# count               3353761   3353761  3353761  3353761.0  3353761.0
# unique                  112     61293        2  2107269.0  2008577.0
# top     2020-12-19 00:00:00  03:00:00  REGULAR        0.0        0.0
# freq                  31271    270084  3339952    47039.0   133680.0
# first   2020-11-28 00:00:00       NaN      NaN        NaN        NaN
# last    2021-03-19 00:00:00       NaN      NaN        NaN        NaN

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3353761 entries, 0 to 3353760
# Data columns (total 11 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   CA        object
#  1   UNIT      object
#  2   SCP       object
#  3   STATION   object
#  4   LINENAME  object
#  5   DIVISION  object
#  6   DATE      datetime64[ns]
#  7   TIME      object
#  8   DESC      object
#  9   ENTRIES   object
#  10  EXITS     object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 281.5+ MB
